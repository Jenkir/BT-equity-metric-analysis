# %%
## Grow the City's Population:  State of MD
### Households with children, total households, working age population
## 2019

# %%
# data source: 2019 Census Data (ACS-1 year) for Selected Variables - Maryland

# %%
#pip install censusdata

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

from us import states
import censusdata

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\BT-equity-metric-analysis'

# %%
# need to change the working directory; be sure that the config file for the census API is also in this folder
#os.chdir('C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs')

# %%
#os.getcwd()

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('max_colwidth', 100)

# %%
# American Community Survey 1-Year Data 

data = censusdata.download('acs1', 2019,
                          censusdata.censusgeo([('state', '24'),
                                               ]),
                                        ["B11005_002E","B19001_001E","B01003_001E", "B01002_001E",
                                         "B02001_002E", "B02001_003E","B03001_003E"])
                          
census_2019 = pd.DataFrame(data)
census_2019
# Out:
#                                         B11005_002E  B19001_001E  B01003_001E  \
# Maryland: Summary level: 040, state:24       688650      2226767      6045680
#
#                                         B01002_001E  B02001_002E  B02001_003E  \
# Maryland: Summary level: 040, state:24         39.0      3296909      1830059
#
#                                         B03001_003E
# Maryland: Summary level: 040, state:24       643171

# %%
# Pull age values from the ACS 1 yr. census codes/ variables listed and save them in the variable "age_data"
age_data = censusdata.download('acs1', 2019,
                          censusdata.censusgeo([('state', '24'),
                                               ]),
                                         ["B01001_003E",                                    
                                          "B01001_004E",
                                          "B01001_005E",
                                          "B01001_006E",
                                          "B01001_007E",
                                          "B01001_008E",
                                          "B01001_009E",
                                          "B01001_010E",
                                          "B01001_011E",
                                          "B01001_012E",
                                          "B01001_013E",
                                          "B01001_014E",
                                          "B01001_015E",
                                          "B01001_016E",            
                                          "B01001_017E",
                                          "B01001_018E",
                                          "B01001_019E",
                                          "B01001_020E",
                                          "B01001_021E",
                                          "B01001_022E",
                                          "B01001_023E",
                                          "B01001_024E",
                                          "B01001_025E",
                                          "B01001_027E",
                                          "B01001_028E",
                                          "B01001_029E",
                                          "B01001_030E",
                                          "B01001_031E",
                                          "B01001_032E",
                                          "B01001_033E",
                                          "B01001_034E",
                                          "B01001_035E",
                                          "B01001_036E",
                                          "B01001_037E",
                                          "B01001_038E",
                                          "B01001_039E",            
                                          "B01001_040E",
                                          "B01001_041E",
                                          "B01001_042E",
                                          "B01001_043E",
                                          "B01001_044E",
                                          "B01001_045E",
                                          "B01001_046E",
                                          "B01001_047E",
                                          "B01001_048E",
                                          "B01001_049E"])
age_2019 = pd.DataFrame(age_data)
age_2019.head()
# Out:
#                                         B01001_003E  B01001_004E  B01001_005E  \
# Maryland: Summary level: 040, state:24       182785       184730       198160
#
#                                         B01001_006E  B01001_007E  B01001_008E  \
# Maryland: Summary level: 040, state:24       112752        80072        41543
#
#                                         B01001_009E  B01001_010E  B01001_011E  \
# Maryland: Summary level: 040, state:24        38090       110859       204453
#
#                                         B01001_012E  ...  B01001_040E  \
# Maryland: Summary level: 040, state:24       204600  ...       213305
#
#                                         B01001_041E  B01001_042E  B01001_043E  \
# Maryland: Summary level: 040, state:24       216599        88632       126597
#
#                                         B01001_044E  B01001_045E  B01001_046E  \
# Maryland: Summary level: 040, state:24        74133        98987       135612
#
#                                         B01001_047E  B01001_048E  B01001_049E
# Maryland: Summary level: 040, state:24        93449        68842        74017
#
# [1 rows x 46 columns]

# %%
# Sum columns of age groups that are under 18 years old for male and female and add new column "Pop. <18 years"
columns_under18 = ["B01001_003E",                                    
                   "B01001_004E",
                   "B01001_005E",
                   "B01001_006E",
                   "B01001_027E",
                   "B01001_028E",
                   "B01001_029E",
                   "B01001_030E"]
age_2019['Pop. <18 years']= age_2019[columns_under18].sum(axis=1)
age_2019.head()
# Out:
#                                         B01001_003E  B01001_004E  B01001_005E  \
# Maryland: Summary level: 040, state:24       182785       184730       198160
#
#                                         B01001_006E  B01001_007E  B01001_008E  \
# Maryland: Summary level: 040, state:24       112752        80072        41543
#
#                                         B01001_009E  B01001_010E  B01001_011E  \
# Maryland: Summary level: 040, state:24        38090       110859       204453
#
#                                         B01001_012E  ...  B01001_041E  \
# Maryland: Summary level: 040, state:24       204600  ...       216599
#
#                                         B01001_042E  B01001_043E  B01001_044E  \
# Maryland: Summary level: 040, state:24        88632       126597        74133
#
#                                         B01001_045E  B01001_046E  B01001_047E  \
# Maryland: Summary level: 040, state:24        98987       135612        93449
#
#                                         B01001_048E  B01001_049E  \
# Maryland: Summary level: 040, state:24        68842        74017
#
#                                         Pop. <18 years
# Maryland: Summary level: 040, state:24         1332287
#
# [1 rows x 47 columns]

# %%
# Sum columns of age groups that are 18-64 years old (working age) for male and female and add new column "Pop. working age"
columns_working_age_2019 = [                                    
                   "B01001_007E",
                   "B01001_008E",
                   "B01001_009E",
                   "B01001_010E",
                   "B01001_011E",
                   "B01001_012E",   
                   "B01001_013E",
                   "B01001_014E",    
                   "B01001_015E",    
                   "B01001_016E",   
                   "B01001_017E", 
                   "B01001_018E",    
                   "B01001_019E",    
                   "B01001_031E",
                   "B01001_032E",
                   "B01001_033E",
                   "B01001_034E",
                   "B01001_035E",   
                   "B01001_036E",
                   "B01001_037E",    
                   "B01001_038E",    
                   "B01001_039E",   
                   "B01001_040E", 
                   "B01001_041E",    
                   "B01001_042E",    
                   "B01001_043E"]    
                           
age_2019['Pop. working age']= age_2019[columns_working_age_2019].sum(axis=1)
age_2019.head()
# Out:
#                                         B01001_003E  B01001_004E  B01001_005E  \
# Maryland: Summary level: 040, state:24       182785       184730       198160
#
#                                         B01001_006E  B01001_007E  B01001_008E  \
# Maryland: Summary level: 040, state:24       112752        80072        41543
#
#                                         B01001_009E  B01001_010E  B01001_011E  \
# Maryland: Summary level: 040, state:24        38090       110859       204453
#
#                                         B01001_012E  ...  B01001_042E  \
# Maryland: Summary level: 040, state:24       204600  ...        88632
#
#                                         B01001_043E  B01001_044E  B01001_045E  \
# Maryland: Summary level: 040, state:24       126597        74133        98987
#
#                                         B01001_046E  B01001_047E  B01001_048E  \
# Maryland: Summary level: 040, state:24       135612        93449        68842
#
#                                         B01001_049E  Pop. <18 years  \
# Maryland: Summary level: 040, state:24        74017         1332287
#
#                                         Pop. working age
# Maryland: Summary level: 040, state:24           3753506
#
# [1 rows x 48 columns]

# %%
# Sum columns of age groups that are 65+ years old for male and female and add new column "Pop. 65+ years"
columns_senior_2019 = ["B01001_020E",
                  "B01001_021E",
                  "B01001_022E",
                  "B01001_023E",                                    
                  "B01001_024E",
                  "B01001_025E",
                  "B01001_044E",
                  "B01001_045E",
                  "B01001_046E",
                  "B01001_047E",                                    
                  "B01001_048E",
                  "B01001_049E"]               
                          
age_2019['Pop. 65+ years']= age_2019[columns_senior_2019].sum(axis=1)
age_2019.head()
# Out:
#                                         B01001_003E  B01001_004E  B01001_005E  \
# Maryland: Summary level: 040, state:24       182785       184730       198160
#
#                                         B01001_006E  B01001_007E  B01001_008E  \
# Maryland: Summary level: 040, state:24       112752        80072        41543
#
#                                         B01001_009E  B01001_010E  B01001_011E  \
# Maryland: Summary level: 040, state:24        38090       110859       204453
#
#                                         B01001_012E  ...  B01001_043E  \
# Maryland: Summary level: 040, state:24       204600  ...       126597
#
#                                         B01001_044E  B01001_045E  B01001_046E  \
# Maryland: Summary level: 040, state:24        74133        98987       135612
#
#                                         B01001_047E  B01001_048E  B01001_049E  \
# Maryland: Summary level: 040, state:24        93449        68842        74017
#
#                                         Pop. <18 years  Pop. working age  \
# Maryland: Summary level: 040, state:24         1332287           3753506
#
#                                         Pop. 65+ years
# Maryland: Summary level: 040, state:24          959887
#
# [1 rows x 49 columns]

# %%
age_final_2019 = age_2019[["Pop. <18 years", "Pop. working age", "Pop. 65+ years"]]
age_final_2019.head()
# Out:
#                                         Pop. <18 years  Pop. working age  \
# Maryland: Summary level: 040, state:24         1332287           3753506
#
#                                         Pop. 65+ years
# Maryland: Summary level: 040, state:24          959887

# %%
age_final = age_final_2019.copy()
age_final
# Out:
#                                         Pop. <18 years  Pop. working age  \
# Maryland: Summary level: 040, state:24         1332287           3753506
#
#                                         Pop. 65+ years
# Maryland: Summary level: 040, state:24          959887

# %%
age_final.index = ['Maryland, 2019']
age_final
# Out:
#                 Pop. <18 years  Pop. working age  Pop. 65+ years
# Maryland, 2019         1332287           3753506          959887

# %%
age_final = age_final.reset_index()
age_final
# Out:
#             index  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Maryland, 2019         1332287           3753506          959887

# %%
age_final = age_final.rename(columns={"index": "Year"})                                           
age_final
# Out:
#              Year  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Maryland, 2019         1332287           3753506          959887

# %%
age_final.dtypes
# Out:
# Year                object
# Pop. <18 years       int64
# Pop. working age     int64
# Pop. 65+ years       int64
# dtype: object

# %%
# Replace the census variable codes (such as "B19013_001E") in the dataframe with text so it's understandable
census_2019 = census_2019.rename(columns={"B11005_002E": "Households with one or more people under 18 years",
                                      "B19001_001E": "Total households",
                                      "B01003_001E": "Population",
                                      "B01002_001E": "Median age",
                                      "B02001_003E": "Pop. Black",
                                      "B02001_002E": "Pop. white",
                                      "B03001_003E": "Pop. Hispanic origin"
                                         })
census_2019.head()
# Out:
#                                         Households with one or more people under 18 years  \
# Maryland: Summary level: 040, state:24                                             688650
#
#                                         Total households  Population  \
# Maryland: Summary level: 040, state:24           2226767     6045680
#
#                                         Median age  Pop. white  Pop. Black  \
# Maryland: Summary level: 040, state:24        39.0     3296909     1830059
#
#                                         Pop. Hispanic origin
# Maryland: Summary level: 040, state:24                643171

# %%
census = census_2019.copy()
census
# Out:
#                                         Households with one or more people under 18 years  \
# Maryland: Summary level: 040, state:24                                             688650
#
#                                         Total households  Population  \
# Maryland: Summary level: 040, state:24           2226767     6045680
#
#                                         Median age  Pop. white  Pop. Black  \
# Maryland: Summary level: 040, state:24        39.0     3296909     1830059
#
#                                         Pop. Hispanic origin
# Maryland: Summary level: 040, state:24                643171

# %%
census.index = ['Maryland, 2019']
census
# Out:
#                 Households with one or more people under 18 years  \
# Maryland, 2019                                             688650
#
#                 Total households  Population  Median age  Pop. white  \
# Maryland, 2019           2226767     6045680        39.0     3296909
#
#                 Pop. Black  Pop. Hispanic origin
# Maryland, 2019     1830059                643171

# %%
census = census.reset_index()
census
# Out:
#             index  Households with one or more people under 18 years  \
# 0  Maryland, 2019                                             688650
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0           2226767     6045680        39.0     3296909     1830059
#
#    Pop. Hispanic origin
# 0                643171

# %%
census = census.rename(columns={"index": "Year"})                                           
census
# Out:
#              Year  Households with one or more people under 18 years  \
# 0  Maryland, 2019                                             688650
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0           2226767     6045680        39.0     3296909     1830059
#
#    Pop. Hispanic origin
# 0                643171

# %%
# combine the census_2019 dataframe with the age_final_2019 dataframe 
population_2019 = pd.merge(
    census, age_final, on="Year", how="outer")
population_2019
# Out:
#              Year  Households with one or more people under 18 years  \
# 0  Maryland, 2019                                             688650
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0           2226767     6045680        39.0     3296909     1830059
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0                643171         1332287           3753506          959887

# %%
population_2019["Percent working age"] = 100 * \
    population_2019["Pop. working age"].astype(
        int) / population_2019["Population"].astype(
        int) 

population_2019["Percent working age"] = population_2019["Percent working age"].astype(int)

# %%
population_2019["Percent households with children"] = 100 * \
    population_2019["Households with one or more people under 18 years"].astype(
        int) / population_2019["Total households"].astype(
        int) 

population_2019["Percent households with children"] = population_2019["Percent households with children"].astype(int)
population_2019
# Out:
#              Year  Households with one or more people under 18 years  \
# 0  Maryland, 2019                                             688650
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0           2226767     6045680        39.0     3296909     1830059
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years  \
# 0                643171         1332287           3753506          959887
#
#    Percent working age  Percent households with children
# 0                   62                                30

# %%
# Export file as a CSV, without the Pandas index, but with the header
population_2019.to_csv("MD_population_2019.csv", index = False, header=True)
