# %%
## Grow the City's Population:
### Households with children, total households, working age population
## 2017

# %%
# data source: 2017 Census Data (ACS-1 year) for Selected Variables - Baltimore City

# %%
#pip install cenpy
# From https://cenpy-devs.github.io/cenpy/

# %%
# From https://www.census.gov/programs-surveys/acs/guidance/comparing-acs-data.html:
# "Due to the impact of the COVID-19 pandemic, the Census Bureau changed the 2020 ACS release. 
# Instead of providing the standard 1-year data products, the Census Bureau released experimental estimates from the 1-year data. 
# Data users should not compare 2020 ACS 1-year experimental estimates with any other data.""

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

from us import states
import censusdata

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs'

# %%
# need to change the working directory; be sure that the config file for the census API is also in this folder
os.chdir('C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs'

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('max_colwidth', 100)

# %%
# American Community Survey 1-Year Data 

data = censusdata.download('acs1', 2017,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '510')]),
                                        ["B11005_002E","B19001_001E","B01003_001E", "B01002_001E",
                                         "B02001_002E", "B02001_003E","B03001_003E"])
                          
census_2017 = pd.DataFrame(data)
census_2017
# Out:
#                                                                     B11005_002E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        59831
#
#                                                                     B19001_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       240280
#
#                                                                     B01003_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       611648
#
#                                                                     B01002_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         35.3
#
#                                                                     B02001_002E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       183988
#
#                                                                     B02001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       383508
#
#                                                                     B03001_003E
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        32495

# %%
# Pull age values from the ACS 1 yr. census codes/ variables listed and save them in the variable "age_data"
age_data = censusdata.download('acs1', 2017,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '510')]),
                                         ["B01001_003E",                                    
                                          "B01001_004E",
                                          "B01001_005E",
                                          "B01001_006E",
                                          "B01001_007E",
                                          "B01001_008E",
                                          "B01001_009E",
                                          "B01001_010E",
                                          "B01001_011E",
                                          "B01001_012E",
                                          "B01001_013E",
                                          "B01001_014E",
                                          "B01001_015E",
                                          "B01001_016E",            
                                          "B01001_017E",
                                          "B01001_018E",
                                          "B01001_019E",
                                          "B01001_020E",
                                          "B01001_021E",
                                          "B01001_022E",
                                          "B01001_023E",
                                          "B01001_024E",
                                          "B01001_025E",
                                          "B01001_027E",
                                          "B01001_028E",
                                          "B01001_029E",
                                          "B01001_030E",
                                          "B01001_031E",
                                          "B01001_032E",
                                          "B01001_033E",
                                          "B01001_034E",
                                          "B01001_035E",
                                          "B01001_036E",
                                          "B01001_037E",
                                          "B01001_038E",
                                          "B01001_039E",            
                                          "B01001_040E",
                                          "B01001_041E",
                                          "B01001_042E",
                                          "B01001_043E",
                                          "B01001_044E",
                                          "B01001_045E",
                                          "B01001_046E",
                                          "B01001_047E",
                                          "B01001_048E",
                                          "B01001_049E"])
age_2017 = pd.DataFrame(age_data)
age_2017.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19712
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        16273
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        18113
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9206
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7787
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4586
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4190
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11723
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        29837
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26254
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_040E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19870
#
#                                                                     B01001_041E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        22400
#
#                                                                     B01001_042E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8812
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11456
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7162
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9460
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11378
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7309
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6981
#
#                                                                     B01001_049E
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7057
#
# [1 rows x 46 columns]

# %%
# Sum columns of age groups that are under 18 years old for male and female and add new column "Pop. <18 years"
columns_under18 = ["B01001_003E",                                    
                   "B01001_004E",
                   "B01001_005E",
                   "B01001_006E",
                   "B01001_027E",
                   "B01001_028E",
                   "B01001_029E",
                   "B01001_030E"]
age_2017['Pop. <18 years']= age_2017[columns_under18].sum(axis=1)
age_2017.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19712
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        16273
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        18113
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9206
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7787
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4586
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4190
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11723
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        29837
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26254
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_041E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        22400
#
#                                                                     B01001_042E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8812
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11456
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7162
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9460
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11378
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7309
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6981
#
#                                                                     B01001_049E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7057
#
#                                                                     Pop. <18 years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          126007
#
# [1 rows x 47 columns]

# %%
# Sum columns of age groups that are 18-64 years old (working age) for male and female and add new column "Pop. working age"
columns_working_age_2017 = [                                    
                   "B01001_007E",
                   "B01001_008E",
                   "B01001_009E",
                   "B01001_010E",
                   "B01001_011E",
                   "B01001_012E",   
                   "B01001_013E",
                   "B01001_014E",    
                   "B01001_015E",    
                   "B01001_016E",   
                   "B01001_017E", 
                   "B01001_018E",    
                   "B01001_019E",    
                   "B01001_031E",
                   "B01001_032E",
                   "B01001_033E",
                   "B01001_034E",
                   "B01001_035E",   
                   "B01001_036E",
                   "B01001_037E",    
                   "B01001_038E",    
                   "B01001_039E",   
                   "B01001_040E", 
                   "B01001_041E",    
                   "B01001_042E",    
                   "B01001_043E"]    
                           
age_2017['Pop. working age']= age_2017[columns_working_age_2017].sum(axis=1)
age_2017.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19712
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        16273
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        18113
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9206
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7787
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4586
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4190
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11723
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        29837
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26254
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_042E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8812
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11456
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7162
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9460
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11378
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7309
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6981
#
#                                                                     B01001_049E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7057
#
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          126007
#
#                                                                     Pop. working age
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            403089
#
# [1 rows x 48 columns]

# %%
# Sum columns of age groups that are 65+ years old for male and female and add new column "Pop. 65+ years"
columns_senior_2017 = ["B01001_020E",
                  "B01001_021E",
                  "B01001_022E",
                  "B01001_023E",                                    
                  "B01001_024E",
                  "B01001_025E",
                  "B01001_044E",
                  "B01001_045E",
                  "B01001_046E",
                  "B01001_047E",                                    
                  "B01001_048E",
                  "B01001_049E"]               
                          
age_2017['Pop. 65+ years']= age_2017[columns_senior_2017].sum(axis=1)
age_2017.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19712
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        16273
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        18113
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9206
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7787
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4586
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         4190
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11723
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        29837
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26254
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11456
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7162
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9460
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        11378
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7309
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6981
#
#                                                                     B01001_049E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7057
#
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          126007
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            403089
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           82552
#
# [1 rows x 49 columns]

# %%
age_final_2017 = age_2017[["Pop. <18 years", "Pop. working age", "Pop. 65+ years"]]
age_final_2017.head()
# Out:
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          126007
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            403089
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           82552

# %%
age_final = age_final_2017.copy()
age_final
# Out:
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          126007
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            403089
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           82552

# %%
age_final.index = ['Baltimore, 2017']
age_final
# Out:
#                  Pop. <18 years  Pop. working age  Pop. 65+ years
# Baltimore, 2017          126007            403089           82552

# %%
age_final = age_final.reset_index()
age_final
# Out:
#              index  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Baltimore, 2017          126007            403089           82552

# %%
age_final = age_final.rename(columns={"index": "Year"})                                           
age_final
# Out:
#               Year  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Baltimore, 2017          126007            403089           82552

# %%
age_final.dtypes
# Out:
# Year                object
# Pop. <18 years       int64
# Pop. working age     int64
# Pop. 65+ years       int64
# dtype: object

# %%
# Replace the census variable codes (such as "B19013_001E") in the dataframe with text so it's understandable
census_2017 = census_2017.rename(columns={"B11005_002E": "Households with one or more people under 18 years",
                                      "B19001_001E": "Total households",
                                      "B01003_001E": "Population",
                                      "B01002_001E": "Median age",
                                      "B02001_003E": "Pop. Black",
                                      "B02001_002E": "Pop. white",
                                      "B03001_003E": "Pop. Hispanic origin"
                                         })
census_2017.head()
# Out:
#                                                                     Households with one or more people under 18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                                              59831
#
#                                                                     Total households  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            240280
#
#                                                                     Population  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      611648
#
#                                                                     Median age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        35.3
#
#                                                                     Pop. white  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      183988
#
#                                                                     Pop. Black  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      383508
#
#                                                                     Pop. Hispanic origin
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                 32495

# %%
census = census_2017.copy()
census
# Out:
#                                                                     Households with one or more people under 18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                                              59831
#
#                                                                     Total households  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            240280
#
#                                                                     Population  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      611648
#
#                                                                     Median age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        35.3
#
#                                                                     Pop. white  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      183988
#
#                                                                     Pop. Black  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      383508
#
#                                                                     Pop. Hispanic origin
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                 32495

# %%
census.index = ['Baltimore, 2017']
census
# Out:
#                  Households with one or more people under 18 years  \
# Baltimore, 2017                                              59831
#
#                  Total households  Population  Median age  Pop. white  \
# Baltimore, 2017            240280      611648        35.3      183988
#
#                  Pop. Black  Pop. Hispanic origin
# Baltimore, 2017      383508                 32495

# %%
census = census.reset_index()
census
# Out:
#              index  Households with one or more people under 18 years  \
# 0  Baltimore, 2017                                              59831
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240280      611648        35.3      183988      383508
#
#    Pop. Hispanic origin
# 0                 32495

# %%
census = census.rename(columns={"index": "Year"})                                           
census
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2017                                              59831
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240280      611648        35.3      183988      383508
#
#    Pop. Hispanic origin
# 0                 32495

# %%
# combine the census_2017 dataframe with the age_final_2017 dataframe 
population_2017 = pd.merge(
    census, age_final, on="Year", how="outer")
population_2017
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2017                                              59831
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240280      611648        35.3      183988      383508
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0                 32495          126007            403089           82552

# %%
population_2017["Percent working age"] = 100 * \
    population_2017["Pop. working age"].astype(
        int) / population_2017["Population"].astype(
        int) 

population_2017["Percent working age"] = population_2017["Percent working age"].astype(int)

# %%
population_2017["Percent households with children"] = 100 * \
    population_2017["Households with one or more people under 18 years"].astype(
        int) / population_2017["Total households"].astype(
        int) 

population_2017["Percent households with children"] = population_2017["Percent households with children"].astype(int)
population_2017
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2017                                              59831
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240280      611648        35.3      183988      383508
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years  \
# 0                 32495          126007            403089           82552
#
#    Percent working age  Percent households with children
# 0                   65                                24

# %%
# Export file as a CSV, without the Pandas index, but with the header
population_2017.to_csv("ACS_population_2017.csv", index = False, header=True)
