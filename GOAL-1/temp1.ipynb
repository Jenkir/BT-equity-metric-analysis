# %%
## Build an equitable economy

#Unemployment and labor participation rates

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# import Baltimore data
bdata_2015 = "balt_employment_2015.csv"
bdata_2016 = "balt_employment_2016.csv"
bdata_2017 = "balt_employment_2017.csv"
bdata_2018 = "balt_employment_2018.csv"
bdata_2019 = "balt_employment_2019.csv"
bdata_2021 = "balt_employment_2021.csv"

# %%
# import MD data
mdata_2015 = "MD_employment_2015.csv"
mdata_2016 = "MD_employment_2016.csv"
mdata_2017 = "MD_employment_2017.csv"
mdata_2018 = "MD_employment_2018.csv"
mdata_2019 = "MD_employment_2019.csv"
mdata_2021 = "MD_employment_2021.csv"

# %%
# import U.S. data
usdata_2015 = "us_employment_2015.csv"
usdata_2016 = "us_employment_2016.csv"
usdata_2017 = "us_employment_2017.csv"
usdata_2018 = "us_employment_2018.csv"
usdata_2019 = "us_employment_2019.csv"
usdata_2021 = "us_employment_2021.csv"

# %%
bdf_2015 = pd.read_csv(bdata_2015)
bdf_2015
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2015                                      598106
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   136746                        502319
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          301809              270992                 30358  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
#
#    White labor participation
# 0                       66.7

# %%
bdf_2015.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2016 = pd.read_csv(bdata_2016)
bdf_2016
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2016                                      593353
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   130053                        498366
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          312075              283328                 27759  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                8.9                13.2                 3.4
#
#    Labor participation rate  Black labor participation  \
# 0                      62.6                       58.7
#
#    White labor participation
# 0                       69.5

# %%
bdf_2016.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2017 = pd.read_csv(bdata_2017)
bdf_2017
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2017                                      588922
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   130980                        498844
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          307585              284018                 23261  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                7.6                10.4                 3.5
#
#    Labor participation rate  Black labor participation  \
# 0                      61.7                       57.9
#
#    White labor participation
# 0                       68.2

# %%
bdf_2017.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2018 = pd.read_csv(bdata_2018)
bdf_2018
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2018                                      580628
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   107073                        491977
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          307604              286050                 20745  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                6.8                 8.9                 3.8
#
#    Labor participation rate  Black labor participation  \
# 0                      62.5                       57.2
#
#    White labor participation
# 0                       71.3

# %%
bdf_2018.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2019 = pd.read_csv(bdata_2019)
bdf_2019
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2019                                      570960
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   115472                        485560
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          303032              280352                 22110  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                7.3                  10                 3.4
#
#    Labor participation rate  Black labor participation  \
# 0                      62.4                         58
#
#    White labor participation
# 0                       69.2

# %%
bdf_2019.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2021 = pd.read_csv(bdata_2021)
bdf_2021
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2021.0                                    552925.0
# 1     NaN                                         NaN
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 127135.0                      472136.0
# 1                                      NaN                           NaN
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        294220.0            270242.0               23252.0  Baltimore
# 1             NaN                 NaN                   NaN        NaN
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                7.9                10.1                 5.0
# 1                NaN                 NaN                 NaN
#
#    Labor participation rate  Black labor participation  \
# 0                      62.3                       56.6
# 1                       NaN                        NaN
#
#    White labor participation  Unnamed: 14  Unnamed: 15
# 0                       71.7          NaN          NaN
# 1                        NaN          NaN          NaN

# %%
bdf_2021.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation', 'Unnamed: 14',
#        'Unnamed: 15'],
#       dtype='object')

# %%
# Combine all of the baltimore dataframes using pd.concat
dfb1 = pd.concat([bdf_2015,bdf_2016,bdf_2017,bdf_2018,bdf_2019,bdf_2021], axis=0, sort=False)
dfb1
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                    598106.0
# 0  2016.0                                    593353.0
# 0  2017.0                                    588922.0
# 0  2018.0                                    580628.0
# 0  2019.0                                    570960.0
# 0  2021.0                                    552925.0
# 1     NaN                                         NaN
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
# 1                                      NaN                           NaN
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        301809.0            270992.0               30358.0  Baltimore
# 0        312075.0            283328.0               27759.0  Baltimore
# 0        307585.0            284018.0               23261.0  Baltimore
# 0        307604.0            286050.0               20745.0  Baltimore
# 0        303032.0            280352.0               22110.0  Baltimore
# 0        294220.0            270242.0               23252.0  Baltimore
# 1             NaN                 NaN                   NaN        NaN
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
# 0                8.9                13.2                 3.4
# 0                7.6                10.4                 3.5
# 0                6.8                 8.9                 3.8
# 0                7.3                10.0                 3.4
# 0                7.9                10.1                 5.0
# 1                NaN                 NaN                 NaN
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
# 0                      62.6                       58.7
# 0                      61.7                       57.9
# 0                      62.5                       57.2
# 0                      62.4                       58.0
# 0                      62.3                       56.6
# 1                       NaN                        NaN
#
#    White labor participation  Unnamed: 14  Unnamed: 15
# 0                       66.7          NaN          NaN
# 0                       69.5          NaN          NaN
# 0                       68.2          NaN          NaN
# 0                       71.3          NaN          NaN
# 0                       69.2          NaN          NaN
# 0                       71.7          NaN          NaN
# 1                        NaN          NaN          NaN

# %%
dfb3 = dfb1.dropna(axis=0, how='all')
dfb3
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                    598106.0
# 0  2016.0                                    593353.0
# 0  2017.0                                    588922.0
# 0  2018.0                                    580628.0
# 0  2019.0                                    570960.0
# 0  2021.0                                    552925.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        301809.0            270992.0               30358.0  Baltimore
# 0        312075.0            283328.0               27759.0  Baltimore
# 0        307585.0            284018.0               23261.0  Baltimore
# 0        307604.0            286050.0               20745.0  Baltimore
# 0        303032.0            280352.0               22110.0  Baltimore
# 0        294220.0            270242.0               23252.0  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
# 0                8.9                13.2                 3.4
# 0                7.6                10.4                 3.5
# 0                6.8                 8.9                 3.8
# 0                7.3                10.0                 3.4
# 0                7.9                10.1                 5.0
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
# 0                      62.6                       58.7
# 0                      61.7                       57.9
# 0                      62.5                       57.2
# 0                      62.4                       58.0
# 0                      62.3                       56.6
#
#    White labor participation  Unnamed: 14  Unnamed: 15
# 0                       66.7          NaN          NaN
# 0                       69.5          NaN          NaN
# 0                       68.2          NaN          NaN
# 0                       71.3          NaN          NaN
# 0                       69.2          NaN          NaN
# 0                       71.7          NaN          NaN

# %%
dfb3 = dfb3.dropna(axis=1, how='all')
dfb3.head()
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                    598106.0
# 0  2016.0                                    593353.0
# 0  2017.0                                    588922.0
# 0  2018.0                                    580628.0
# 0  2019.0                                    570960.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        301809.0            270992.0               30358.0  Baltimore
# 0        312075.0            283328.0               27759.0  Baltimore
# 0        307585.0            284018.0               23261.0  Baltimore
# 0        307604.0            286050.0               20745.0  Baltimore
# 0        303032.0            280352.0               22110.0  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
# 0                8.9                13.2                 3.4
# 0                7.6                10.4                 3.5
# 0                6.8                 8.9                 3.8
# 0                7.3                10.0                 3.4
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
# 0                      62.6                       58.7
# 0                      61.7                       57.9
# 0                      62.5                       57.2
# 0                      62.4                       58.0
#
#    White labor participation
# 0                       66.7
# 0                       69.5
# 0                       68.2
# 0                       71.3
# 0                       69.2

# %%
dfb3.dtypes
# Out:
# Year                                          float64
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfb3 = dfb3.astype({"Year": 'int'})
dfb3.dtypes
# Out:
# Year                                            int32
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfb3 = dfb3.astype({"Year": 'string'})
dfb3.dtypes
# Out:
# Year                                           string
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfb3 = dfb3.rename(columns={"Median HH income White Alone Householder": "Median white hh income",
                            "Median HH income Black or African American Alone Householder": "Median Black hh income"
                           })
dfb3
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2015                                    598106.0
# 0  2016                                    593353.0
# 0  2017                                    588922.0
# 0  2018                                    580628.0
# 0  2019                                    570960.0
# 0  2021                                    552925.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        301809.0            270992.0               30358.0  Baltimore
# 0        312075.0            283328.0               27759.0  Baltimore
# 0        307585.0            284018.0               23261.0  Baltimore
# 0        307604.0            286050.0               20745.0  Baltimore
# 0        303032.0            280352.0               22110.0  Baltimore
# 0        294220.0            270242.0               23252.0  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
# 0                8.9                13.2                 3.4
# 0                7.6                10.4                 3.5
# 0                6.8                 8.9                 3.8
# 0                7.3                10.0                 3.4
# 0                7.9                10.1                 5.0
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
# 0                      62.6                       58.7
# 0                      61.7                       57.9
# 0                      62.5                       57.2
# 0                      62.4                       58.0
# 0                      62.3                       56.6
#
#    White labor participation
# 0                       66.7
# 0                       69.5
# 0                       68.2
# 0                       71.3
# 0                       69.2
# 0                       71.7

# %%
dfb3.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
# change order of columns
dfb = dfb3.loc[:,['Location', 'Year','Persons for whom poverty status determined',
       'Individuals- income below poverty level',
       'Population 16 years and over', 'In labor force', 'Employed civilians',
       'Unemployed civilians', 'Location', 'Unemployment rate',
       'Black unemployment', 'White unemployment', 'Labor participation rate',
       'Black labor participation', 'White labor participation', 
       ]]
dfb
# Out:
#     Location  Year  Persons for whom poverty status determined  \
# 0  Baltimore  2015                                    598106.0
# 0  Baltimore  2016                                    593353.0
# 0  Baltimore  2017                                    588922.0
# 0  Baltimore  2018                                    580628.0
# 0  Baltimore  2019                                    570960.0
# 0  Baltimore  2021                                    552925.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        301809.0            270992.0               30358.0  Baltimore
# 0        312075.0            283328.0               27759.0  Baltimore
# 0        307585.0            284018.0               23261.0  Baltimore
# 0        307604.0            286050.0               20745.0  Baltimore
# 0        303032.0            280352.0               22110.0  Baltimore
# 0        294220.0            270242.0               23252.0  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
# 0                8.9                13.2                 3.4
# 0                7.6                10.4                 3.5
# 0                6.8                 8.9                 3.8
# 0                7.3                10.0                 3.4
# 0                7.9                10.1                 5.0
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
# 0                      62.6                       58.7
# 0                      61.7                       57.9
# 0                      62.5                       57.2
# 0                      62.4                       58.0
# 0                      62.3                       56.6
#
#    White labor participation
# 0                       66.7
# 0                       69.5
# 0                       68.2
# 0                       71.3
# 0                       69.2
# 0                       71.7

# %%
mdf_2015 = pd.read_csv(mdata_2015)
mdf_2016 = pd.read_csv(mdata_2016)
mdf_2017 = pd.read_csv(mdata_2017)
mdf_2018 = pd.read_csv(mdata_2018)
mdf_2019 = pd.read_csv(mdata_2019)
mdf_2021 = pd.read_csv(mdata_2021)

# %%
# Combine all of the Maryland dataframes using pd.concat
dfm1 = pd.concat([mdf_2015,mdf_2016,mdf_2017,mdf_2018,mdf_2019,mdf_2021], axis=0, sort=False)
dfm1
# Out:
#       Year  Persons for whom poverty status determined  \
# 0   2015.0                                   5863290.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
# 4      NaN                                         NaN
# 0   2016.0                                   5875026.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
# 4      NaN                                         NaN
# 5      NaN                                         NaN
# 6      NaN                                         NaN
# 7      NaN                                         NaN
# 8      NaN                                         NaN
# 9      NaN                                         NaN
# 10     NaN                                         NaN
# 11     NaN                                         NaN
# 12     NaN                                         NaN
# 0   2017.0                                   5915309.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
# 4      NaN                                         NaN
# 5      NaN                                         NaN
# 6      NaN                                         NaN
# 0   2018.0                                   5899819.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 0   2019.0                                   5898360.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
# 4      NaN                                         NaN
# 0   2021.0                                   6023847.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
#
#     Individuals- income below poverty level  Population 16 years and over  \
# 0                                  570776.0                     4814546.0
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 0                                  567715.0                     4819956.0
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
# 6                                       NaN                           NaN
# 7                                       NaN                           NaN
# 8                                       NaN                           NaN
# 9                                       NaN                           NaN
# 10                                      NaN                           NaN
# 11                                      NaN                           NaN
# 12                                      NaN                           NaN
# 0                                  549171.0                     4855374.0
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
# 6                                       NaN                           NaN
# 0                                  528203.0                     4852950.0
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 0                                  532241.0                     4862424.0
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 0                                  618372.0                     4964751.0
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
#
#     In labor force  Employed civilians  Unemployed civilians  Location  \
# 0        3238521.0           3031466.0              175802.0  Maryland
# 1              NaN                 NaN                   NaN       NaN
# 2              NaN                 NaN                   NaN       NaN
# 3              NaN                 NaN                   NaN       NaN
# 4              NaN                 NaN                   NaN       NaN
# 0        3277687.0           3073923.0              175235.0  Maryland
# 1              NaN                 NaN                   NaN       NaN
# 2              NaN                 NaN                   NaN       NaN
# 3              NaN                 NaN                   NaN       NaN
# 4              NaN                 NaN                   NaN       NaN
# 5              NaN                 NaN                   NaN       NaN
# 6              NaN                 NaN                   NaN       NaN
# 7              NaN                 NaN                   NaN       NaN
# 8              NaN                 NaN                   NaN       NaN
# 9              NaN                 NaN                   NaN       NaN
# 10             NaN                 NaN                   NaN       NaN
# 11             NaN                 NaN                   NaN       NaN
# 12             NaN                 NaN                   NaN       NaN
# 0        3294443.0           3098182.0              170419.0  Maryland
# 1              NaN                 NaN                   NaN       NaN
# 2              NaN                 NaN                   NaN       NaN
# 3              NaN                 NaN                   NaN       NaN
# 4              NaN                 NaN                   NaN       NaN
# 5              NaN                 NaN                   NaN       NaN
# 6              NaN                 NaN                   NaN       NaN
# 0        3283636.0           3090469.0              160777.0  Maryland
# 1              NaN                 NaN                   NaN       NaN
# 2              NaN                 NaN                   NaN       NaN
# 0        3279799.0           3098870.0              147356.0  Maryland
# 1              NaN                 NaN                   NaN       NaN
# 2              NaN                 NaN                   NaN       NaN
# 3              NaN                 NaN                   NaN       NaN
# 4              NaN                 NaN                   NaN       NaN
# 0        3304168.0           3070750.0              192275.0  Maryland
# 1              NaN                 NaN                   NaN       NaN
# 2              NaN                 NaN                   NaN       NaN
# 3              NaN                 NaN                   NaN       NaN
#
#     Unemployment rate  Black unemployment  White unemployment  \
# 0                 4.0                 7.9                 4.2
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 0                 4.0                 7.7                 4.3
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 5                 NaN                 NaN                 NaN
# 6                 NaN                 NaN                 NaN
# 7                 NaN                 NaN                 NaN
# 8                 NaN                 NaN                 NaN
# 9                 NaN                 NaN                 NaN
# 10                NaN                 NaN                 NaN
# 11                NaN                 NaN                 NaN
# 12                NaN                 NaN                 NaN
# 0                 4.0                 7.6                 4.1
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 5                 NaN                 NaN                 NaN
# 6                 NaN                 NaN                 NaN
# 0                 3.0                 7.1                 3.8
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 0                 3.0                 6.9                 3.4
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 0                 4.0                 8.4                 4.3
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
#
#     Labor participation rate  Black labor participation  \
# 0                       67.3                       67.2
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 0                       68.0                       68.4
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 0                       67.9                       68.5
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 0                       67.7                       68.0
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 0                       67.5                       67.3
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 0                       66.6                       66.4
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
#
#     White labor participation  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0                        66.3          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN          NaN          NaN          NaN
# 0                        66.8          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN          NaN          NaN          NaN
# 5                         NaN          NaN          NaN          NaN
# 6                         NaN          NaN          NaN          NaN
# 7                         NaN          NaN          NaN          NaN
# 8                         NaN          NaN          NaN          NaN
# 9                         NaN          NaN          NaN          NaN
# 10                        NaN          NaN          NaN          NaN
# 11                        NaN          NaN          NaN          NaN
# 12                        NaN          NaN          NaN          NaN
# 0                        66.5          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN          NaN          NaN          NaN
# 5                         NaN          NaN          NaN          NaN
# 6                         NaN          NaN          NaN          NaN
# 0                        66.3          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 0                        66.3          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN          NaN          NaN          NaN
# 0                        65.3          NaN          NaN          NaN
# 1                         NaN          NaN          NaN          NaN
# 2                         NaN          NaN          NaN          NaN
# 3                         NaN          NaN          NaN          NaN

# %%
dfm3 = dfm1.dropna(axis=0, how='all')
dfm3
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                   5863290.0
# 0  2016.0                                   5875026.0
# 0  2017.0                                   5915309.0
# 0  2018.0                                   5899819.0
# 0  2019.0                                   5898360.0
# 0  2021.0                                   6023847.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 570776.0                     4814546.0
# 0                                 567715.0                     4819956.0
# 0                                 549171.0                     4855374.0
# 0                                 528203.0                     4852950.0
# 0                                 532241.0                     4862424.0
# 0                                 618372.0                     4964751.0
#
#    In labor force  Employed civilians  Unemployed civilians  Location  \
# 0       3238521.0           3031466.0              175802.0  Maryland
# 0       3277687.0           3073923.0              175235.0  Maryland
# 0       3294443.0           3098182.0              170419.0  Maryland
# 0       3283636.0           3090469.0              160777.0  Maryland
# 0       3279799.0           3098870.0              147356.0  Maryland
# 0       3304168.0           3070750.0              192275.0  Maryland
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                4.0                 7.9                 4.2
# 0                4.0                 7.7                 4.3
# 0                4.0                 7.6                 4.1
# 0                3.0                 7.1                 3.8
# 0                3.0                 6.9                 3.4
# 0                4.0                 8.4                 4.3
#
#    Labor participation rate  Black labor participation  \
# 0                      67.3                       67.2
# 0                      68.0                       68.4
# 0                      67.9                       68.5
# 0                      67.7                       68.0
# 0                      67.5                       67.3
# 0                      66.6                       66.4
#
#    White labor participation  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0                       66.3          NaN          NaN          NaN
# 0                       66.8          NaN          NaN          NaN
# 0                       66.5          NaN          NaN          NaN
# 0                       66.3          NaN          NaN          NaN
# 0                       66.3          NaN          NaN          NaN
# 0                       65.3          NaN          NaN          NaN

# %%
dfm3 = dfm3.dropna(axis=1, how='all')
dfm3
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                   5863290.0
# 0  2016.0                                   5875026.0
# 0  2017.0                                   5915309.0
# 0  2018.0                                   5899819.0
# 0  2019.0                                   5898360.0
# 0  2021.0                                   6023847.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 570776.0                     4814546.0
# 0                                 567715.0                     4819956.0
# 0                                 549171.0                     4855374.0
# 0                                 528203.0                     4852950.0
# 0                                 532241.0                     4862424.0
# 0                                 618372.0                     4964751.0
#
#    In labor force  Employed civilians  Unemployed civilians  Location  \
# 0       3238521.0           3031466.0              175802.0  Maryland
# 0       3277687.0           3073923.0              175235.0  Maryland
# 0       3294443.0           3098182.0              170419.0  Maryland
# 0       3283636.0           3090469.0              160777.0  Maryland
# 0       3279799.0           3098870.0              147356.0  Maryland
# 0       3304168.0           3070750.0              192275.0  Maryland
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                4.0                 7.9                 4.2
# 0                4.0                 7.7                 4.3
# 0                4.0                 7.6                 4.1
# 0                3.0                 7.1                 3.8
# 0                3.0                 6.9                 3.4
# 0                4.0                 8.4                 4.3
#
#    Labor participation rate  Black labor participation  \
# 0                      67.3                       67.2
# 0                      68.0                       68.4
# 0                      67.9                       68.5
# 0                      67.7                       68.0
# 0                      67.5                       67.3
# 0                      66.6                       66.4
#
#    White labor participation
# 0                       66.3
# 0                       66.8
# 0                       66.5
# 0                       66.3
# 0                       66.3
# 0                       65.3

# %%
dfm3.dtypes
# Out:
# Year                                          float64
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfm3 = dfm3.astype({"Year":'int'})

# %%
dfm3 = dfm3.astype({"Year":'string'})
dfm3.dtypes
# Out:
# Year                                           string
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
# change order of columns
dfm = dfm1.loc[:,['Location', 'Year','Population','Pop. Black','Pop. white','Median household income','Median Black hh income',
            'Median white hh income']]
dfm
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17688\354821191.py in <module>
#       1 # change order of columns
#       2 dfm = dfm1.loc[:,['Location', 'Year','Population','Pop. Black','Pop. white','Median household income','Median Black hh income',
# ----> 3             'Median white hh income']]
#       4 dfm
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['Population', 'Pop. Black', 'Pop. white', 'Median household income', 'Median Black hh income', 'Median white hh income'] not in index"

# %%
usdf_2015 = pd.read_csv(usdata_2015)
usdf_2016 = pd.read_csv(usdata_2016)
usdf_2017 = pd.read_csv(usdata_2017)
usdf_2018 = pd.read_csv(usdata_2018)
usdf_2019 = pd.read_csv(usdata_2019)
usdf_2021 = pd.read_csv(usdata_2021)

# %%
# Combine all of the U.S. dataframes using pd.concat
dfus1 = pd.concat([usdf_2015,usdf_2016,usdf_2017,usdf_2018,usdf_2019,usdf_2021], axis=0, sort=False)
dfus1

# %%
dfus = dfus1.rename(columns={"Median hh income white": "Median white hh income",
                            "Median hh income Black": "Median Black hh income"
                           })
dfus

# %%
# Combine all of the remaining dataframes using pd.concat
Goal1_income = pd.concat([dfb,dfm,dfus], axis=0, sort=False)
Goal1_income

# %%
Goal1_income.reset_index()

# %%
# Using drop=True will remove the old "index" column
Goal1_income.reset_index(drop=True)

# %%
Goal1_income.dtypes

# %%
# Export file as an Excel file, to be imported into Tableau
Goal1_income.to_excel("./viz_source_files/Goal1_income.xlsx", index=False)

# %%
Goal1_mapped = Goal1_income.copy()

# %%
# see https://towardsdatascience.com/apply-thousand-separator-and-other-formatting-to-pandas-dataframe-45f2f4c7ab01
#Goal1_formatted.loc[:,"Median household income_formatted"] ='$'+ Goal1_mapped["Median household income"].map('{:,.0f}'.format)

#Goal1_formatted
