# %%
## Build an equitable economy

#Unemployment and labor participation rates

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# import Baltimore data
bdata_2015 = "balt_employment_2015.csv"
bdata_2016 = "balt_employment_2016.csv"
bdata_2017 = "balt_employment_2017.csv"
bdata_2018 = "balt_employment_2018.csv"
bdata_2019 = "balt_employment_2019.csv"
bdata_2021 = "balt_employment_2021.csv"

# %%
# import MD data
mdata_2015 = "MD_employment_2015.csv"
mdata_2016 = "MD_employment_2016.csv"
mdata_2017 = "MD_employment_2017.csv"
mdata_2018 = "MD_employment_2018.csv"
mdata_2019 = "MD_employment_2019.csv"
mdata_2021 = "MD_employment_2021.csv"

# %%
# import U.S. data
usdata_2015 = "us_employment_2015.csv"
usdata_2016 = "us_employment_2016.csv"
usdata_2017 = "us_employment_2017.csv"
usdata_2018 = "us_employment_2018.csv"
usdata_2019 = "us_employment_2019.csv"
usdata_2021 = "us_employment_2021.csv"

# %%
bdf_2015 = pd.read_csv(bdata_2015)
bdf_2015
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2015                                      598106
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   136746                        502319
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          301809              270992                 30358  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0               10.1                14.4                 3.7
#
#    Labor participation rate  Black labor participation  \
# 0                      60.1                       55.8
#
#    White labor participation
# 0                       66.7

# %%
bdf_2015.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2016 = pd.read_csv(bdata_2016)
bdf_2016
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2016                                      593353
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   130053                        498366
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          312075              283328                 27759  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                8.9                13.2                 3.4
#
#    Labor participation rate  Black labor participation  \
# 0                      62.6                       58.7
#
#    White labor participation
# 0                       69.5

# %%
bdf_2016.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2017 = pd.read_csv(bdata_2017)
bdf_2017
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2017                                      588922
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   130980                        498844
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          307585              284018                 23261  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                7.6                10.4                 3.5
#
#    Labor participation rate  Black labor participation  \
# 0                      61.7                       57.9
#
#    White labor participation
# 0                       68.2

# %%
bdf_2017.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2018 = pd.read_csv(bdata_2018)
bdf_2018
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2018                                      580628
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   107073                        491977
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          307604              286050                 20745  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                6.8                 8.9                 3.8
#
#    Labor participation rate  Black labor participation  \
# 0                      62.5                       57.2
#
#    White labor participation
# 0                       71.3

# %%
bdf_2018.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2019 = pd.read_csv(bdata_2019)
bdf_2019
# Out:
#    Year  Persons for whom poverty status determined  \
# 0  2019                                      570960
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                   115472                        485560
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0          303032              280352                 22110  Baltimore
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                7.3                  10                 3.4
#
#    Labor participation rate  Black labor participation  \
# 0                      62.4                         58
#
#    White labor participation
# 0                       69.2

# %%
bdf_2019.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
bdf_2021 = pd.read_csv(bdata_2021)
bdf_2021
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2021.0                                    552925.0
# 1     NaN                                         NaN
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 127135.0                      472136.0
# 1                                      NaN                           NaN
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        294220.0            270242.0               23252.0  Baltimore
# 1             NaN                 NaN                   NaN        NaN
#
#    Unemployment rate  Black unemployment  White unemployment  \
# 0                7.9                10.1                 5.0
# 1                NaN                 NaN                 NaN
#
#    Labor participation rate  Black labor participation  \
# 0                      62.3                       56.6
# 1                       NaN                        NaN
#
# ...

# %%
bdf_2021.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation', 'Unnamed: 14',
#        'Unnamed: 15'],
#       dtype='object')

# %%
# Combine all of the baltimore dataframes using pd.concat
dfb1 = pd.concat([bdf_2015,bdf_2016,bdf_2017,bdf_2018,bdf_2019,bdf_2021], axis=0, sort=False)
dfb1
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                    598106.0
# 0  2016.0                                    593353.0
# 0  2017.0                                    588922.0
# 0  2018.0                                    580628.0
# 0  2019.0                                    570960.0
# 0  2021.0                                    552925.0
# 1     NaN                                         NaN
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
# ...

# %%
dfb3 = dfb1.dropna(axis=0, how='all')
dfb3
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                    598106.0
# 0  2016.0                                    593353.0
# 0  2017.0                                    588922.0
# 0  2018.0                                    580628.0
# 0  2019.0                                    570960.0
# 0  2021.0                                    552925.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
#
# ...

# %%
dfb3 = dfb3.dropna(axis=1, how='all')
dfb3.head()
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                    598106.0
# 0  2016.0                                    593353.0
# 0  2017.0                                    588922.0
# 0  2018.0                                    580628.0
# 0  2019.0                                    570960.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
#
#    In labor force  Employed civilians  Unemployed civilians   Location  \
# 0        301809.0            270992.0               30358.0  Baltimore
# ...

# %%
dfb3.dtypes
# Out:
# Year                                          float64
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfb3 = dfb3.astype({"Year": 'int'})
dfb3.dtypes
# Out:
# Year                                            int32
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfb3 = dfb3.astype({"Year": 'string'})
dfb3.dtypes
# Out:
# Year                                           string
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# dtype: object

# %%
dfb3.columns
# Out:
# Index(['Year', 'Persons for whom poverty status determined',
#        'Individuals- income below poverty level',
#        'Population 16 years and over', 'In labor force', 'Employed civilians',
#        'Unemployed civilians', 'Location', 'Unemployment rate',
#        'Black unemployment', 'White unemployment', 'Labor participation rate',
#        'Black labor participation', 'White labor participation'],
#       dtype='object')

# %%
# change order of columns
dfb = dfb3.loc[:,['Location', 'Year','Persons for whom poverty status determined',
       'Individuals- income below poverty level',
       'Population 16 years and over', 'In labor force', 'Employed civilians',
       'Unemployed civilians', 'Unemployment rate',
       'Black unemployment', 'White unemployment', 'Labor participation rate',
       'Black labor participation', 'White labor participation', 
       ]]
dfb
# Out:
#     Location  Year  Persons for whom poverty status determined  \
# 0  Baltimore  2015                                    598106.0
# 0  Baltimore  2016                                    593353.0
# 0  Baltimore  2017                                    588922.0
# 0  Baltimore  2018                                    580628.0
# 0  Baltimore  2019                                    570960.0
# 0  Baltimore  2021                                    552925.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 136746.0                      502319.0
# 0                                 130053.0                      498366.0
# 0                                 130980.0                      498844.0
# 0                                 107073.0                      491977.0
# 0                                 115472.0                      485560.0
# 0                                 127135.0                      472136.0
#
# ...

# %%
mdf_2015 = pd.read_csv(mdata_2015)
mdf_2016 = pd.read_csv(mdata_2016)
mdf_2017 = pd.read_csv(mdata_2017)
mdf_2018 = pd.read_csv(mdata_2018)
mdf_2019 = pd.read_csv(mdata_2019)
mdf_2021 = pd.read_csv(mdata_2021)

# %%
# Combine all of the Maryland dataframes using pd.concat
dfm1 = pd.concat([mdf_2015,mdf_2016,mdf_2017,mdf_2018,mdf_2019,mdf_2021], axis=0, sort=False)
dfm1
# Out:
#       Year  Persons for whom poverty status determined  \
# 0   2015.0                                   5863290.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
# 4      NaN                                         NaN
# 0   2016.0                                   5875026.0
# 1      NaN                                         NaN
# 2      NaN                                         NaN
# 3      NaN                                         NaN
# 4      NaN                                         NaN
# 5      NaN                                         NaN
# 6      NaN                                         NaN
# 7      NaN                                         NaN
# 8      NaN                                         NaN
# 9      NaN                                         NaN
# 10     NaN                                         NaN
# ...

# %%
dfm1 = dfm1.dropna(axis=0, how='all')
dfm1
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                   5863290.0
# 0  2016.0                                   5875026.0
# 0  2017.0                                   5915309.0
# 0  2018.0                                   5899819.0
# 0  2019.0                                   5898360.0
# 0  2021.0                                   6023847.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 570776.0                     4814546.0
# 0                                 567715.0                     4819956.0
# 0                                 549171.0                     4855374.0
# 0                                 528203.0                     4852950.0
# 0                                 532241.0                     4862424.0
# 0                                 618372.0                     4964751.0
#
# ...

# %%
dfm1 = dfm1.dropna(axis=0, how='all')
dfm1
# Out:
#      Year  Persons for whom poverty status determined  \
# 0  2015.0                                   5863290.0
# 0  2016.0                                   5875026.0
# 0  2017.0                                   5915309.0
# 0  2018.0                                   5899819.0
# 0  2019.0                                   5898360.0
# 0  2021.0                                   6023847.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 570776.0                     4814546.0
# 0                                 567715.0                     4819956.0
# 0                                 549171.0                     4855374.0
# 0                                 528203.0                     4852950.0
# 0                                 532241.0                     4862424.0
# 0                                 618372.0                     4964751.0
#
# ...

# %%
dfm1.dtypes
# Out:
# Year                                          float64
# Persons for whom poverty status determined    float64
# Individuals- income below poverty level       float64
# Population 16 years and over                  float64
# In labor force                                float64
# Employed civilians                            float64
# Unemployed civilians                          float64
# Location                                       object
# Unemployment rate                             float64
# Black unemployment                            float64
# White unemployment                            float64
# Labor participation rate                      float64
# Black labor participation                     float64
# White labor participation                     float64
# Unnamed: 14                                   float64
# Unnamed: 15                                   float64
# Unnamed: 16                                   float64
# dtype: object

# %%
dfm1 = dfm1.astype({'Year':'int'})

# %%
dfm1 = dfm1.astype({'Year':'string'})

# %%
# change order of columns
dfm = dfm1.loc[:,['Location', 'Year','Persons for whom poverty status determined',
       'Individuals- income below poverty level',
       'Population 16 years and over', 'In labor force', 'Employed civilians',
       'Unemployed civilians', 'Unemployment rate',
       'Black unemployment', 'White unemployment', 'Labor participation rate',
       'Black labor participation', 'White labor participation', 
       ]]
dfm
# Out:
#    Location  Year  Persons for whom poverty status determined  \
# 0  Maryland  2015                                   5863290.0
# 0  Maryland  2016                                   5875026.0
# 0  Maryland  2017                                   5915309.0
# 0  Maryland  2018                                   5899819.0
# 0  Maryland  2019                                   5898360.0
# 0  Maryland  2021                                   6023847.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                                 570776.0                     4814546.0
# 0                                 567715.0                     4819956.0
# 0                                 549171.0                     4855374.0
# 0                                 528203.0                     4852950.0
# 0                                 532241.0                     4862424.0
# 0                                 618372.0                     4964751.0
#
# ...

# %%
usdf_2015 = pd.read_csv(usdata_2015)
usdf_2016 = pd.read_csv(usdata_2016)
usdf_2017 = pd.read_csv(usdata_2017)
usdf_2018 = pd.read_csv(usdata_2018)
usdf_2019 = pd.read_csv(usdata_2019)
usdf_2021 = pd.read_csv(usdata_2021)

# %%
# Combine all of the U.S. dataframes using pd.concat
dfus1 = pd.concat([usdf_2015,usdf_2016,usdf_2017,usdf_2018,usdf_2019,usdf_2021], axis=0, sort=False)
dfus1
# Out:
#         Location    Year  Persons for whom poverty status determined  \
# 0  United States  2015.0                                 313476400.0
# 1            NaN     NaN                                         NaN
# 2            NaN     NaN                                         NaN
# 3            NaN     NaN                                         NaN
# 4            NaN     NaN                                         NaN
# 0  United States  2016.0                                 315165470.0
# 1            NaN     NaN                                         NaN
# 2            NaN     NaN                                         NaN
# 3            NaN     NaN                                         NaN
# 4            NaN     NaN                                         NaN
# 0  United States  2017.0                                 317741588.0
# 1            NaN     NaN                                         NaN
# 2            NaN     NaN                                         NaN
# ...

# %%
dfus1 = dfus1.dropna(axis=0, how='all')
dfus1
# Out:
#         Location    Year  Persons for whom poverty status determined  \
# 0  United States  2015.0                                 313476400.0
# 0  United States  2016.0                                 315165470.0
# 0  United States  2017.0                                 317741588.0
# 0  United States  2018.0                                 319184033.0
# 0  United States  2019.0                                 320118791.0
# 0  United States  2021.0                                 324173084.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                               46153077.0                   256167758.0
# 0                               44268996.0                   257950721.0
# 0                               42583651.0                   260564248.0
# 0                               41852315.0                   262185951.0
# 0                               39490096.0                   263534161.0
# ...

# %%
dfus1 = dfus1.dropna(axis=1, how='all')
dfus1
# Out:
#         Location    Year  Persons for whom poverty status determined  \
# 0  United States  2015.0                                 313476400.0
# 0  United States  2016.0                                 315165470.0
# 0  United States  2017.0                                 317741588.0
# 0  United States  2018.0                                 319184033.0
# 0  United States  2019.0                                 320118791.0
# 0  United States  2021.0                                 324173084.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                               46153077.0                   256167758.0
# 0                               44268996.0                   257950721.0
# 0                               42583651.0                   260564248.0
# 0                               41852315.0                   262185951.0
# 0                               39490096.0                   263534161.0
# ...

# %%
dfus2 = dfus1.astype({'Year':'int'})

# %%
dfus2 = dfus2.astype({"Year":"string"})

# %%
# change order of columns
dfus = dfus2.loc[:,['Location', 'Year','Persons for whom poverty status determined',
       'Individuals- income below poverty level',
       'Population 16 years and over', 'In labor force', 'Employed civilians',
       'Unemployed civilians', 'Unemployment rate',
       'Black unemployment', 'White unemployment', 'Labor participation rate',
       'Black labor participation', 'White labor participation', 
       ]]

# %%
dfus
# Out:
#         Location  Year  Persons for whom poverty status determined  \
# 0  United States  2015                                 313476400.0
# 0  United States  2016                                 315165470.0
# 0  United States  2017                                 317741588.0
# 0  United States  2018                                 319184033.0
# 0  United States  2019                                 320118791.0
# 0  United States  2021                                 324173084.0
#
#    Individuals- income below poverty level  Population 16 years and over  \
# 0                               46153077.0                   256167758.0
# 0                               44268996.0                   257950721.0
# 0                               42583651.0                   260564248.0
# 0                               41852315.0                   262185951.0
# 0                               39490096.0                   263534161.0
# ...

# %%
# Combine all of the remaining dataframes using pd.concat
Goal1_employment = pd.concat([dfb,dfm,dfus], axis=0, sort=False)
Goal1_employment
# Out:
#         Location  Year  Persons for whom poverty status determined  \
# 0      Baltimore  2015                                    598106.0
# 0      Baltimore  2016                                    593353.0
# 0      Baltimore  2017                                    588922.0
# 0      Baltimore  2018                                    580628.0
# 0      Baltimore  2019                                    570960.0
# 0      Baltimore  2021                                    552925.0
# 0       Maryland  2015                                   5863290.0
# 0       Maryland  2016                                   5875026.0
# 0       Maryland  2017                                   5915309.0
# 0       Maryland  2018                                   5899819.0
# 0       Maryland  2019                                   5898360.0
# 0       Maryland  2021                                   6023847.0
# 0  United States  2015                                 313476400.0
# ...

# %%
Goal1_employment.reset_index()
# Out:
#     index       Location  Year  Persons for whom poverty status determined  \
# 0       0      Baltimore  2015                                    598106.0
# 1       0      Baltimore  2016                                    593353.0
# 2       0      Baltimore  2017                                    588922.0
# 3       0      Baltimore  2018                                    580628.0
# 4       0      Baltimore  2019                                    570960.0
# 5       0      Baltimore  2021                                    552925.0
# 6       0       Maryland  2015                                   5863290.0
# 7       0       Maryland  2016                                   5875026.0
# 8       0       Maryland  2017                                   5915309.0
# 9       0       Maryland  2018                                   5899819.0
# 10      0       Maryland  2019                                   5898360.0
# ...

# %%
# Using drop=True will remove the old "index" column
Goal1_employment.reset_index(drop=True)
# Out:
#          Location  Year  Persons for whom poverty status determined  \
# 0       Baltimore  2015                                    598106.0
# 1       Baltimore  2016                                    593353.0
# 2       Baltimore  2017                                    588922.0
# 3       Baltimore  2018                                    580628.0
# 4       Baltimore  2019                                    570960.0
# 5       Baltimore  2021                                    552925.0
# 6        Maryland  2015                                   5863290.0
# 7        Maryland  2016                                   5875026.0
# 8        Maryland  2017                                   5915309.0
# 9        Maryland  2018                                   5899819.0
# 10       Maryland  2019                                   5898360.0
# 11       Maryland  2021                                   6023847.0
# 12  United States  2015                                 313476400.0
# ...

# %%
# Export file as an Excel file, to be imported into Tableau
Goal1_employment.to_excel("./viz_source_files/Goal1_employment.xlsx", index=False)

# %%
#Goal1_mapped = Goal1_income.copy()

# %%
# see https://towardsdatascience.com/apply-thousand-separator-and-other-formatting-to-pandas-dataframe-45f2f4c7ab01
#Goal1_formatted.loc[:,"Median household income_formatted"] ='$'+ Goal1_mapped["Median household income"].map('{:,.0f}'.format)

#Goal1_formatted
