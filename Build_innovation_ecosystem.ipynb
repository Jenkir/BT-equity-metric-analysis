# %%
# Dependencies

import pandas as pd

# %%
# import csv of data downloaded from the Census QWI website (cleaned in Excel)
data = "raw_data_census/bfs_newbusiness_applications_for_jupyter_import.csv"

# %%
df = pd.read_csv(data)
df
# Out:
#       Geographical area  Applications  Year
# 0   Anne Arundel County          5537  2017
# 1      Baltimore County          9703  2017
# 2        Carroll County          1182  2017
# 3        Harford County          2020  2017
# 4         Howard County          3776  2017
# 5   Queen Anne's County           484  2017
# 6        Baltimore City          8402  2017
# 7   Anne Arundel County          5537  2017
# 8      Baltimore County          9703  2017
# 9        Carroll County          1182  2017
# 10       Harford County          2020  2017
# 11        Howard County          3776  2017
# 12  Queen Anne's County           484  2017
# 13       Baltimore City          8402  2017
# 14  Anne Arundel County          5894  2018
# 15     Baltimore County         10946  2018
# 16       Carroll County          1243  2018
# 17       Harford County          2023  2018
# 18        Howard County          4165  2018
# 19  Queen Anne's County           462  2018
# ...

# %%
df.dtypes
# Out:
# Geographical area    object
# Applications          int64
# Year                  int64
# dtype: object

# %%
df["Year"] = df["Year"].astype(str)
df.dtypes
# Out:
# Geographical area    object
# Applications          int64
# Year                 object
# dtype: object

# %%
df.to_excel("Tableau_from_jupyternb/Build_innovation_business_applications.xlsx", index=False)
