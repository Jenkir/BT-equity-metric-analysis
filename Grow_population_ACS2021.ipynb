# %% [markdown]
# ## Grow the City's Population:
# ### Households with children, total households, working age population
# ## 2021

# %%
# data source: 2021 Census Data (ACS-1 year) for Selected Variables - Baltimore City

# %%
#pip install cenpy
# From https://cenpy-devs.github.io/cenpy/

# %%
# From https://www.census.gov/programs-surveys/acs/guidance/comparing-acs-data.html:
# "Due to the impact of the COVID-19 pandemic, the Census Bureau changed the 2020 ACS release. 
# Instead of providing the standard 1-year data products, the Census Bureau released experimental estimates from the 1-year data. 
# Data users should not compare 2020 ACS 1-year experimental estimates with any other data.""

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

from us import states
import censusdata

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs'

# %%
# need to change the working directory; be sure that the config file for the census API is also in this folder
os.chdir('C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs'

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('max_colwidth', 100)

# %%
# American Community Survey 1-Year Data 

data = censusdata.download('acs1', 2021,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '510')]),
                                        ["B11005_002E","B19001_001E","B01003_001E", "B01002_001E",
                                         "B02001_002E", "B02001_003E","B03001_003E"])
                          
census_2021 = pd.DataFrame(data)
census_2021
# Out:
#                                                                     B11005_002E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        55571
#
#                                                                     B19001_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       254370
#
#                                                                     B01003_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       576498
#
#                                                                     B01002_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         36.1
#
#                                                                     B02001_002E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       159246
#
#                                                                     B02001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       344531
#
#                                                                     B03001_003E
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        34810

# %%
# Pull age values from the ACS 1 yr. census codes/ variables listed and save them in the variable "age_data"
age_data = censusdata.download('acs1', 2021,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '510')]),
                                         ["B01001_003E",                                    
                                          "B01001_004E",
                                          "B01001_005E",
                                          "B01001_006E",
                                          "B01001_007E",
                                          "B01001_008E",
                                          "B01001_009E",
                                          "B01001_010E",
                                          "B01001_011E",
                                          "B01001_012E",
                                          "B01001_013E",
                                          "B01001_014E",
                                          "B01001_015E",
                                          "B01001_016E",            
                                          "B01001_017E",
                                          "B01001_018E",
                                          "B01001_019E",
                                          "B01001_020E",
                                          "B01001_021E",
                                          "B01001_022E",
                                          "B01001_023E",
                                          "B01001_024E",
                                          "B01001_025E",
                                          "B01001_027E",
                                          "B01001_028E",
                                          "B01001_029E",
                                          "B01001_030E",
                                          "B01001_031E",
                                          "B01001_032E",
                                          "B01001_033E",
                                          "B01001_034E",
                                          "B01001_035E",
                                          "B01001_036E",
                                          "B01001_037E",
                                          "B01001_038E",
                                          "B01001_039E",            
                                          "B01001_040E",
                                          "B01001_041E",
                                          "B01001_042E",
                                          "B01001_043E",
                                          "B01001_044E",
                                          "B01001_045E",
                                          "B01001_046E",
                                          "B01001_047E",
                                          "B01001_048E",
                                          "B01001_049E"])
age_2021 = pd.DataFrame(age_data)
age_2021.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17520
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        14924
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17763
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9302
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7816
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3785
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3202
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        10823
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        24260
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26228
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_040E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        16963
#
#                                                                     B01001_041E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19317
#
#                                                                     B01001_042E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7871
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12957
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8139
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9089
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12898
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7882
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         5983
#
#                                                                     B01001_049E
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6604
#
# [1 rows x 46 columns]

# %%
# Sum columns of age groups that are under 18 years old for male and female and add new column "Pop. <18 years"
columns_under18 = ["B01001_003E",                                    
                   "B01001_004E",
                   "B01001_005E",
                   "B01001_006E",
                   "B01001_027E",
                   "B01001_028E",
                   "B01001_029E",
                   "B01001_030E"]
age_2021['Pop. <18 years']= age_2021[columns_under18].sum(axis=1)
age_2021.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17520
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        14924
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17763
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9302
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7816
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3785
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3202
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        10823
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        24260
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26228
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_041E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        19317
#
#                                                                     B01001_042E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7871
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12957
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8139
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9089
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12898
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7882
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         5983
#
#                                                                     B01001_049E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6604
#
#                                                                     Pop. <18 years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          116862
#
# [1 rows x 47 columns]

# %%
# Sum columns of age groups that are 18-64 years old (working age) for male and female and add new column "Pop. working age"
columns_working_age_2021 = [                                    
                   "B01001_007E",
                   "B01001_008E",
                   "B01001_009E",
                   "B01001_010E",
                   "B01001_011E",
                   "B01001_012E",   
                   "B01001_013E",
                   "B01001_014E",    
                   "B01001_015E",    
                   "B01001_016E",   
                   "B01001_017E", 
                   "B01001_018E",    
                   "B01001_019E",    
                   "B01001_031E",
                   "B01001_032E",
                   "B01001_033E",
                   "B01001_034E",
                   "B01001_035E",   
                   "B01001_036E",
                   "B01001_037E",    
                   "B01001_038E",    
                   "B01001_039E",   
                   "B01001_040E", 
                   "B01001_041E",    
                   "B01001_042E",    
                   "B01001_043E"]    
                           
age_2021['Pop. working age']= age_2021[columns_working_age_2021].sum(axis=1)
age_2021.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17520
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        14924
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17763
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9302
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7816
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3785
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3202
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        10823
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        24260
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26228
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_042E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7871
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12957
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8139
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9089
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12898
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7882
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         5983
#
#                                                                     B01001_049E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6604
#
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          116862
#
#                                                                     Pop. working age
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            374406
#
# [1 rows x 48 columns]

# %%
# Sum columns of age groups that are 65+ years old for male and female and add new column "Pop. 65+ years"
columns_senior_2021 = ["B01001_020E",
                  "B01001_021E",
                  "B01001_022E",
                  "B01001_023E",                                    
                  "B01001_024E",
                  "B01001_025E",
                  "B01001_044E",
                  "B01001_045E",
                  "B01001_046E",
                  "B01001_047E",                                    
                  "B01001_048E",
                  "B01001_049E"]               
                          
age_2021['Pop. 65+ years']= age_2021[columns_senior_2021].sum(axis=1)
age_2021.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17520
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        14924
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17763
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9302
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7816
#
#                                                                     B01001_008E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3785
#
#                                                                     B01001_009E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         3202
#
#                                                                     B01001_010E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        10823
#
#                                                                     B01001_011E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        24260
#
#                                                                     B01001_012E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        26228
#
#                                                                     ...  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510  ...
#
#                                                                     B01001_043E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12957
#
#                                                                     B01001_044E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         8139
#
#                                                                     B01001_045E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9089
#
#                                                                     B01001_046E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        12898
#
#                                                                     B01001_047E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7882
#
#                                                                     B01001_048E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         5983
#
#                                                                     B01001_049E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         6604
#
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          116862
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            374406
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           85230
#
# [1 rows x 49 columns]

# %%
age_final_2021 = age_2021[["Pop. <18 years", "Pop. working age", "Pop. 65+ years"]]
age_final_2021.head()
# Out:
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          116862
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            374406
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           85230

# %%
age_final = age_final_2021.copy()
age_final
# Out:
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          116862
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            374406
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           85230

# %%
age_final.index = ['Baltimore, 2021']
age_final
# Out:
#                  Pop. <18 years  Pop. working age  Pop. 65+ years
# Baltimore, 2021          116862            374406           85230

# %%
age_final = age_final.reset_index()
age_final
# Out:
#              index  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Baltimore, 2021          116862            374406           85230

# %%
age_final = age_final.rename(columns={"index": "Year"})                                           
age_final
# Out:
#               Year  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Baltimore, 2021          116862            374406           85230

# %%
age_final.dtypes
# Out:
# Year                object
# Pop. <18 years       int64
# Pop. working age     int64
# Pop. 65+ years       int64
# dtype: object

# %%
# Replace the census variable codes (such as "B19013_001E") in the dataframe with text so it's understandable
census_2021 = census_2021.rename(columns={"B11005_002E": "Households with one or more people under 18 years",
                                      "B19001_001E": "Total households",
                                      "B01003_001E": "Population",
                                      "B01002_001E": "Median age",
                                      "B02001_003E": "Pop. Black",
                                      "B02001_002E": "Pop. white",
                                      "B03001_003E": "Pop. Hispanic origin"
                                         })
census_2021.head()
# Out:
#                                                                     Households with one or more people under 18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                                              55571
#
#                                                                     Total households  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            254370
#
#                                                                     Population  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      576498
#
#                                                                     Median age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        36.1
#
#                                                                     Pop. white  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      159246
#
#                                                                     Pop. Black  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      344531
#
#                                                                     Pop. Hispanic origin
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                 34810

# %%
census = census_2021.copy()
census
# Out:
#                                                                     Households with one or more people under 18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                                              55571
#
#                                                                     Total households  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            254370
#
#                                                                     Population  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      576498
#
#                                                                     Median age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        36.1
#
#                                                                     Pop. white  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      159246
#
#                                                                     Pop. Black  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      344531
#
#                                                                     Pop. Hispanic origin
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                 34810

# %%
census.index = ['Baltimore, 2021']
census
# Out:
#                  Households with one or more people under 18 years  \
# Baltimore, 2021                                              55571
#
#                  Total households  Population  Median age  Pop. white  \
# Baltimore, 2021            254370      576498        36.1      159246
#
#                  Pop. Black  Pop. Hispanic origin
# Baltimore, 2021      344531                 34810

# %%
census = census.reset_index()
census
# Out:
#              index  Households with one or more people under 18 years  \
# 0  Baltimore, 2021                                              55571
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            254370      576498        36.1      159246      344531
#
#    Pop. Hispanic origin
# 0                 34810

# %%
census = census.rename(columns={"index": "Year"})                                           
census
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2021                                              55571
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            254370      576498        36.1      159246      344531
#
#    Pop. Hispanic origin
# 0                 34810

# %%
# combine the census_2021 dataframe with the age_final_2021 dataframe 
population_2021 = pd.merge(
    census, age_final, on="Year", how="outer")
population_2021
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2021                                              55571
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            254370      576498        36.1      159246      344531
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0                 34810          116862            374406           85230

# %%
population_2021["Percent working age"] = 100 * \
    population_2021["Pop. working age"].astype(
        int) / population_2021["Population"].astype(
        int) 

population_2021["Percent working age"] = population_2021["Percent working age"].astype(int)

# %%
population_2021["Percent households with children"] = 100 * \
    population_2021["Households with one or more people under 18 years"].astype(
        int) / population_2021["Total households"].astype(
        int) 

population_2021["Percent households with children"] = population_2021["Percent households with children"].astype(int)
population_2021
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2021                                              55571
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            254370      576498        36.1      159246      344531
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years  \
# 0                 34810          116862            374406           85230
#
#    Percent working age  Percent households with children
# 0                   64                                21

# %%
# Export file as a CSV, without the Pandas index, but with the header
population_2021.to_csv("ACS_population_2021.csv", index = False, header=True)
