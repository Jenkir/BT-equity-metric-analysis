# %%
## Grow the City's Population:
### Households with children, total households, working age population
## 2016

# %%
# data source: 2016 Census Data (ACS-1 year) for Selected Variables - Baltimore City

# %%
#pip install censusdata

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

from us import states
import censusdata

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\BT-equity-metric-analysis'

# %%
# need to change the working directory; be sure that the config file for the census API is also in this folder
#os.chdir('C:\\Users\\Jenkir\\Desktop\\BDC\\Baltimore_Together\\measuring-success-metrics\\analysis_nbs')

# %%
#os.getcwd()

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('max_colwidth', 100)

# %%
# American Community Survey 1-Year Data 

data = censusdata.download('acs1', 2016,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '510')]),
                                        ["B11005_002E","B19001_001E","B01003_001E", "B01002_001E",
                                         "B02001_002E", "B02001_003E","B03001_003E"])
                          
census_2016 = pd.DataFrame(data)
census_2016
# Out:
#                                                                     B11005_002E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        59079
#
#                                                                     B19001_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       240761
#
#                                                                     B01003_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       614664
#
#                                                                     B01002_001E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         34.9
#
#                                                                     B02001_002E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510       189260
#
#                                                                     B02001_003E  \
# ...

# %%
# Pull age values from the ACS 1 yr. census codes/ variables listed and save them in the variable "age_data"
age_data = censusdata.download('acs1', 2016,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '510')]),
                                         ["B01001_003E",                                    
                                          "B01001_004E",
                                          "B01001_005E",
                                          "B01001_006E",
                                          "B01001_007E",
                                          "B01001_008E",
                                          "B01001_009E",
                                          "B01001_010E",
                                          "B01001_011E",
                                          "B01001_012E",
                                          "B01001_013E",
                                          "B01001_014E",
                                          "B01001_015E",
                                          "B01001_016E",            
                                          "B01001_017E",
                                          "B01001_018E",
                                          "B01001_019E",
                                          "B01001_020E",
                                          "B01001_021E",
                                          "B01001_022E",
                                          "B01001_023E",
                                          "B01001_024E",
                                          "B01001_025E",
                                          "B01001_027E",
                                          "B01001_028E",
                                          "B01001_029E",
                                          "B01001_030E",
                                          "B01001_031E",
                                          "B01001_032E",
                                          "B01001_033E",
                                          "B01001_034E",
                                          "B01001_035E",
                                          "B01001_036E",
                                          "B01001_037E",
                                          "B01001_038E",
                                          "B01001_039E",            
                                          "B01001_040E",
                                          "B01001_041E",
                                          "B01001_042E",
                                          "B01001_043E",
                                          "B01001_044E",
                                          "B01001_045E",
                                          "B01001_046E",
                                          "B01001_047E",
                                          "B01001_048E",
                                          "B01001_049E"])
age_2016 = pd.DataFrame(age_data)
age_2016.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        20462
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17466
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17452
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9783
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7735
#
#                                                                     B01001_008E  \
# ...

# %%
# Sum columns of age groups that are under 18 years old for male and female and add new column "Pop. <18 years"
columns_under18 = ["B01001_003E",                                    
                   "B01001_004E",
                   "B01001_005E",
                   "B01001_006E",
                   "B01001_027E",
                   "B01001_028E",
                   "B01001_029E",
                   "B01001_030E"]
age_2016['Pop. <18 years']= age_2016[columns_under18].sum(axis=1)
age_2016.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        20462
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17466
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17452
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9783
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7735
#
#                                                                     B01001_008E  \
# ...

# %%
# Sum columns of age groups that are 18-64 years old (working age) for male and female and add new column "Pop. working age"
columns_working_age_2016 = [                                    
                   "B01001_007E",
                   "B01001_008E",
                   "B01001_009E",
                   "B01001_010E",
                   "B01001_011E",
                   "B01001_012E",   
                   "B01001_013E",
                   "B01001_014E",    
                   "B01001_015E",    
                   "B01001_016E",   
                   "B01001_017E", 
                   "B01001_018E",    
                   "B01001_019E",    
                   "B01001_031E",
                   "B01001_032E",
                   "B01001_033E",
                   "B01001_034E",
                   "B01001_035E",   
                   "B01001_036E",
                   "B01001_037E",    
                   "B01001_038E",    
                   "B01001_039E",   
                   "B01001_040E", 
                   "B01001_041E",    
                   "B01001_042E",    
                   "B01001_043E"]    
                           
age_2016['Pop. working age']= age_2016[columns_working_age_2016].sum(axis=1)
age_2016.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        20462
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17466
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17452
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9783
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7735
#
#                                                                     B01001_008E  \
# ...

# %%
# Sum columns of age groups that are 65+ years old for male and female and add new column "Pop. 65+ years"
columns_senior_2016 = ["B01001_020E",
                  "B01001_021E",
                  "B01001_022E",
                  "B01001_023E",                                    
                  "B01001_024E",
                  "B01001_025E",
                  "B01001_044E",
                  "B01001_045E",
                  "B01001_046E",
                  "B01001_047E",                                    
                  "B01001_048E",
                  "B01001_049E"]               
                          
age_2016['Pop. 65+ years']= age_2016[columns_senior_2016].sum(axis=1)
age_2016.head()
# Out:
#                                                                     B01001_003E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        20462
#
#                                                                     B01001_004E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17466
#
#                                                                     B01001_005E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        17452
#
#                                                                     B01001_006E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         9783
#
#                                                                     B01001_007E  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510         7735
#
#                                                                     B01001_008E  \
# ...

# %%
age_final_2016 = age_2016[["Pop. <18 years", "Pop. working age", "Pop. 65+ years"]]
age_final_2016.head()
# Out:
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          129154
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            406262
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           79248

# %%
age_final = age_final_2016.copy()
age_final
# Out:
#                                                                     Pop. <18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510          129154
#
#                                                                     Pop. working age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            406262
#
#                                                                     Pop. 65+ years
# Baltimore city, Maryland: Summary level: 050, state:24> county:510           79248

# %%
age_final.index = ['Baltimore, 2016']
age_final
# Out:
#                  Pop. <18 years  Pop. working age  Pop. 65+ years
# Baltimore, 2016          129154            406262           79248

# %%
age_final = age_final.reset_index()
age_final
# Out:
#              index  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Baltimore, 2016          129154            406262           79248

# %%
age_final = age_final.rename(columns={"index": "Year"})                                           
age_final
# Out:
#               Year  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0  Baltimore, 2016          129154            406262           79248

# %%
age_final.dtypes
# Out:
# Year                object
# Pop. <18 years       int64
# Pop. working age     int64
# Pop. 65+ years       int64
# dtype: object

# %%
# Replace the census variable codes (such as "B19013_001E") in the dataframe with text so it's understandable
census_2016 = census_2016.rename(columns={"B11005_002E": "Households with one or more people under 18 years",
                                      "B19001_001E": "Total households",
                                      "B01003_001E": "Population",
                                      "B01002_001E": "Median age",
                                      "B02001_003E": "Pop. Black",
                                      "B02001_002E": "Pop. white",
                                      "B03001_003E": "Pop. Hispanic origin"
                                         })
census_2016.head()
# Out:
#                                                                     Households with one or more people under 18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                                              59079
#
#                                                                     Total households  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            240761
#
#                                                                     Population  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      614664
#
#                                                                     Median age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        34.9
#
#                                                                     Pop. white  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      189260
#
# ...

# %%
census = census_2016.copy()
census
# Out:
#                                                                     Households with one or more people under 18 years  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                                              59079
#
#                                                                     Total households  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510            240761
#
#                                                                     Population  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      614664
#
#                                                                     Median age  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510        34.9
#
#                                                                     Pop. white  \
# Baltimore city, Maryland: Summary level: 050, state:24> county:510      189260
#
# ...

# %%
census.index = ['Baltimore, 2016']
census
# Out:
#                  Households with one or more people under 18 years  \
# Baltimore, 2016                                              59079
#
#                  Total households  Population  Median age  Pop. white  \
# Baltimore, 2016            240761      614664        34.9      189260
#
#                  Pop. Black  Pop. Hispanic origin
# Baltimore, 2016      384465                 31144

# %%
census = census.reset_index()
census
# Out:
#              index  Households with one or more people under 18 years  \
# 0  Baltimore, 2016                                              59079
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240761      614664        34.9      189260      384465
#
#    Pop. Hispanic origin
# 0                 31144

# %%
census = census.rename(columns={"index": "Year"})                                           
census
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2016                                              59079
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240761      614664        34.9      189260      384465
#
#    Pop. Hispanic origin
# 0                 31144

# %%
# combine the census_2016 dataframe with the age_final_2016 dataframe 
population_2016 = pd.merge(
    census, age_final, on="Year", how="outer")
population_2016
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2016                                              59079
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240761      614664        34.9      189260      384465
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years
# 0                 31144          129154            406262           79248

# %%
population_2016["Percent working age"] = 100 * \
    population_2016["Pop. working age"].astype(
        int) / population_2016["Population"].astype(
        int) 

population_2016["Percent working age"] = population_2016["Percent working age"].astype(int)

# %%
population_2016["Percent households with children"] = 100 * \
    population_2016["Households with one or more people under 18 years"].astype(
        int) / population_2016["Total households"].astype(
        int) 

population_2016["Percent households with children"] = population_2016["Percent households with children"].astype(int)
population_2016
# Out:
#               Year  Households with one or more people under 18 years  \
# 0  Baltimore, 2016                                              59079
#
#    Total households  Population  Median age  Pop. white  Pop. Black  \
# 0            240761      614664        34.9      189260      384465
#
#    Pop. Hispanic origin  Pop. <18 years  Pop. working age  Pop. 65+ years  \
# 0                 31144          129154            406262           79248
#
#    Percent working age  Percent households with children
# 0                   66                                24

# %%
# Export file as a CSV, without the Pandas index, but with the header
population_2016.to_csv("ACS_population_2016.csv", index = False, header=True)
